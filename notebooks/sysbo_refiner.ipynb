# %%
import pandas as pd

# %%
df = pd.read_csv('../scraper/src/data/new_sysbo.csv')

# %%
sysbo_df = df.copy()

# %%
sysbo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20542 entries, 0 to 20541
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              20542 non-null  int64
#  1   number                  20542 non-null  int64
#  2   Unnamed: 0.1            20542 non-null  int64
#  3   id                      20542 non-null  int64
#  4   item_number             20542 non-null  int64
#  5   name                    20542 non-null  object
#  6   name2                   16837 non-null  object
#  7   price_with_VAT          20542 non-null  float64
#  8   pant                    1236 non-null   float64
#  9   volume_ml               20542 non-null  float64
#  10  price_per_liter         20542 non-null  float64
#  11  start_sale              20542 non-null  object
#  12  expired                 20542 non-null  int64
#  13  item_group              20542 non-null  object
#  14  type                    12488 non-null  object
#  15  style                   4135 non-null   object
#  16  packaging               20452 non-null  object
#  17  closing                 7580 non-null   object
#  18  origin                  15647 non-null  object
#  19  origin_country          20542 non-null  object
#  20  producer                20442 non-null  object
#  21  supplier                20541 non-null  object
#  22  year_vintage            11019 non-null  float64
#  23  provadargang            0 non-null      float64
#  24  abv                     20542 non-null  object
#  25  assortment              20542 non-null  object
#  26  assortment_text         20452 non-null  object
#  27  ecologic                20542 non-null  int64
#  28  etical                  20542 non-null  int64
#  29  etical_label            75 non-null     object
#  30  kosher                  20542 non-null  int64
#  31  description             6082 non-null   object
#  32  scraped                 20471 non-null  float64
#  33  scraped_beska           2866 non-null   float64
#  34  scraped_fyllighet       5672 non-null   float64
#  35  scraped_sötma           4501 non-null   float64
#  36  scraped_fågel           1701 non-null   float64
#  37  scraped_fläsk           1988 non-null   float64
#  38  scraped_sällskapsdryck  3251 non-null   float64
#  39  scraped_grönsaker       698 non-null    float64
#  40  scraped_lamm            2431 non-null   float64
#  41  scraped_nöt             1993 non-null   float64
#  42  scraped_fisk            1732 non-null   float64
#  43  scraped_vilt            530 non-null    float64
#  44  scraped_strävhet        1170 non-null   float64
#  45  scraped_fruktsyra       2611 non-null   float64
#  46  scraped_ost             243 non-null    float64
#  47  scraped_rökighet        215 non-null    float64
#  48  scraped_avec/digestif   297 non-null    float64
#  49  scraped_aperitif        613 non-null    float64
#  50  scraped_skaldjur        746 non-null    float64
#  51  scraped_asiatiskt       112 non-null    float64
#  52  scraped_kryddstarkt     99 non-null     float64
#  53  scraped_buffémat        290 non-null    float64
#  54  scraped_dessert         239 non-null    float64
# dtypes: float64(29), int64(9), object(17)
# memory usage: 8.6+ MB

# %%
# Translation of groups into english.
group_translation = {
    'Rött vin': 'Red wine',
    'Öl': 'Beer',
    'Vitt vin': 'White vine',
    'Mousserande vin': 'Sparkling wine',
    'Whisky': 'Whisky',
    'Rom': 'Rum',
    'Rosévin': 'Rosé',
    'Aperitif och dessert': 'Appetizer and dessert',
    'Likör': 'Liquor',
    'Gin och Genever': 'Gin and Jenever',
    'Blandlådor vin': 'Mixed box',
    'Akvavit och Kryddat brännvin': 'Aquavit and Spicy brandy',
    'Cider': 'Cider',
    'Cognac': 'Cognac',
    'Vodka och Brännvin': 'Vodka and Brandy',
    'Alkoholfritt': 'Non-alcoholic',
    'Grappa och Marc': 'Grappa and Marc',
    'Sake': 'Sake',
    'Vermouth': 'Vermouth',
}

# %%
items = {
    'number': sysbo_df['number'],
    'name': sysbo_df['name'] + ' ' + sysbo_df['name2'].fillna(''),
    # ABV transformation to numerical feature.
    'abv': pd.to_numeric(sysbo_df['abv'].str.replace('%', '')),
    'price': sysbo_df['price_with_VAT'],
    'volume_ml': sysbo_df['volume_ml'],
    'price_per_liter': sysbo_df['price_per_liter'],
    'group': sysbo_df['item_group'].map(lambda x: group_translation.get(x, 'Other')),
    'type': sysbo_df['type'],
    'style': sysbo_df['style'],
    'country': sysbo_df['origin_country'],
    'bitterness': sysbo_df['scraped_beska'],
    'fullness': sysbo_df['scraped_fyllighet'],
    'sweetness': sysbo_df['scraped_sötma'],
}

# %%
items_df = pd.DataFrame(items)
items_df.set_index('number', inplace=True)
items_df.head()
# Out:
#                                               name   abv  price  volume_ml  \
# number
# 101                                         Renat   37.5  207.0      700.0
# 7548901  Arpepe Valtellina Superiore Stella Retica  13.5  381.0      750.0
# 7521801                      Purcari Freedom Blend  13.5  198.0      750.0
# 8936603                      Midas Golden Pilsner    4.9   27.9      330.0
# 8780501                       Josés Tequila Blanco  40.0  359.0      700.0
#
#          price_per_liter             group        type  \
# number
# 101               295.71  Vodka and Brandy       Vodka
# 7548901           508.00          Red wine         NaN
# 7521801           264.00          Red wine         NaN
# 8936603            84.55              Beer  Ljus lager
# 8780501           512.86             Other     Tequila
#
#                            style    country  bitterness  fullness  sweetness
# number
# 101                          NaN    Sverige         NaN       NaN        NaN
# 7548901                      NaN    Italien         NaN       NaN        NaN
# 7521801                      NaN  Moldavien         NaN       NaN        NaN
# 8936603  Pilsner - tjeckisk stil    Sverige         6.0       6.0        1.0
# 8780501                      NaN     Mexiko         NaN       NaN        NaN

# %%
# Remove duplicate names.
to_keep_df = items_df.reset_index().groupby('name').first()
mask = to_keep_df['number']
items_df = items_df.loc[items_df.index.intersection(mask)]

# %%
items_df.to_csv('../scraper/src/data/sysbo.csv')
