# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl, matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
plt.rcParams["figure.figsize"] = (16,12)
plt.rcParams["figure.edgecolor"] = "black"
plt.rcParams["figure.titlesize"] = 20
plt.rcParams["figure.titleweight"] = "bold"
plt.rcParams["axes.labelsize"] = 18
plt.rcParams["xtick.labelsize"] = 12
plt.rcParams["ytick.labelsize"] = 12

# %matplotlib inline

# %%
sysbo_df = pd.read_csv('../scraper/src/data/new_sysbo.csv', index_col='number')
sysbo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20542 entries, 101 to 7467206
# Data columns (total 53 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              20542 non-null  int64
#  1   id                      20542 non-null  int64
#  2   item_number             20542 non-null  int64
#  3   name                    20542 non-null  object
#  4   name2                   16837 non-null  object
#  5   price_with_VAT          20542 non-null  float64
#  6   pant                    1236 non-null   float64
#  7   volume_ml               20542 non-null  float64
#  8   price_per_liter         20542 non-null  float64
#  9   start_sale              20542 non-null  object
#  10  expired                 20542 non-null  int64
#  11  item_group              20542 non-null  object
#  12  type                    12488 non-null  object
#  13  style                   4135 non-null   object
# ...

# %%
sns.countplot(data=sysbo_df, x='scraped_beska')
# Out:
# <AxesSubplot:xlabel='scraped_beska', ylabel='count'>

# %%
fig, ax = plt.subplots(figsize=(20,12))
sns.countplot(data=sysbo_df, y='item_group', order=sysbo_df['item_group'].value_counts().index, ax=ax)
plt.show()

# %%
sysbo_df['abv'].describe()
# Out:
# count      20542
# unique       412
# top       13.50%
# freq        2145
# Name: abv, dtype: object

# %%
sysbo_df['abv'].map(lambda x: float(x.replace('%', '')))
# Out:
# number
# 101        37.5
# 7548901    13.5
# 7521801    13.5
# 8936603     4.9
# 8780501    40.0
#            ...
# 8521301    48.0
# 7263201    13.0
# 8713102    21.0
# 8755702    21.0
# 7467206    15.0
# Name: abv, Length: 20542, dtype: float64

# %%
sysbo_df['abv'].value_counts().index.str.contains('%').sum()
# Out:
# 412
